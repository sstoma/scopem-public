# %%
"""
In theory this should work with reasonable outputs from PPMS system. One needs certain fields, like System, Year. This
script generates various useful statistics for ScopeM members.

Assumptions:
1. Paid project hours are:
* coming from project LM/EM or other EM projects at 0 / 40 / 200 CHF / h
* when using Hour's value metrics (default)
** if activity brings [0,40)CHF income it is assumed that its duration is equal to the number of hours recorded
   When the income is suggesting more than 40CHF / hour duration is COMPUTED such as each 40CHF correspond to one hour

2. Unpaid project hours are:
* coming from Trials
* coming from personal R&D 

Python: 
* requires python-3.2

:bug:
    None known.
:organization:
    ETH
"""

__authors__="""Szymon Stoma"""
__contact__="xxx"
__license__="Cecill-C"
__date__="17-12-05"
__version__="0.1"
__docformat__= "restructuredtext en"

# ---------------------------------------------------------- imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
 

# ---------------------------------------------------------- const
cfg_sstoma_id = "Stoma Szymon"
cfg_andrzej_id = "Rzepiela Andrzej"
cfg_sfn_id = "Noerrelykke Simon"
cfg_ppms_csv_path = 'detailed-list.csv'
cfg_ppms_csv_path = 'detailed-list-2017.csv'
cfg_hour_baseline = 40 #CHF per h


# ---------------------------------------------------------- reading files & adding columns
# reading and listing headers (tricks and hacks applied to fck strange output format)
df = pd.read_csv(cfg_ppms_csv_path, encoding='cp1250', skiprows=[0])
list(df.columns.values)

# removing records without a project since they are useless
df = df[ pd.notnull(df.Project) ]

# adding month to stratify data
dates = pd.to_datetime(df.Date, format="%d/%m/%Y")
df['Month'] = dates.dt.month
df['Year'] = dates.dt.year

# adding time in hours (decimal)
df['Total Booked Hours'] = df['Length booked'] / 60.

# making sens of Amount* column (* is added when it was not paid yet...)
def convert_amount_starred( a ):
    if a.find('*') == -1: return float(a)
    else: return float(a[:-1])
df['Amount*'] = df['Amount*'].apply(convert_amount_starred)
# money can be stored everywhere
df['Total Charged [CHF]'] = df['Amount*'] + df['Prepaid']

# adding ratio of charged to all (under assumption 40 CHF / hr.)
df['Total Charged Hours'] = df['Total Booked Hours'] * (df['Total Charged [CHF]'] > 0)

# backcalculating: 
# for 0 CHF the actual length will be used
# for >40 CHF the hours will be incrased
df["Hour's value"] = pd.DataFrame([df['Total Booked Hours'], df['Total Charged [CHF]'] / cfg_hour_baseline]).max()

# adding a field for classification
df["PPMS_category"] = "NONE"

# listing columns
list(df.columns.values)

# ---------------------------------------------------------- filtering
# prepare filters

# divide into project types
cat_paid_projects =  (df.Project.str.match('[LE]M/.*') | df.Project.str.match('\d+_\w*') | df.Project.str.match('\d+ \w*') | df.Project.str.match('\d+')) 
cat_unpaid_projects = (df.Project.str.match('_Trials') | df.Project.str.match('_LM/ScopeM/Trials')| df.Project.str.match('0060_Trials')) # currently (2017) some projects which should be Trials are in Paid_projects
cat_rd_personal_dev = df.Project.str.match('.*_PD') | df.Project.str.match('_LM/ScopeM/Scientific Collaboration') 
cat_teaching = (df.Project.str.match('.*(MOOC).*') | df.Project.str.match('_Teach.*') | df.Project.str.match('_LM/ScopeM/Schools') | df.Project.str.match('_Microscopy_Program') )
cat_maintenance = (df.Project.str.match('_Main.*') |  df.Project.str.match('_LM/ScopeM/Maintenance') | df.Project.str.match('EAWAG SP5') | df.Project.str.match('_LM/ScopeM/Visitors') )
cat_rd_other = df.Project.str.match('.*(CellStar|Crispr|Flu).*') | df.Project.str.match('_H2020*') | df.Project.str.match('ETHProj201*')
cat_sstoma = (df.System == cfg_sstoma_id)
cat_sfn = (df.System == cfg_sfn_id)
cat_andrzej = (df.System == cfg_andrzej_id)
cat_ida = (df.System == cfg_sstoma_id) | (df.System == cfg_sfn_id) | (df.System == cfg_andrzej_id)

# assign a PPMS tag based on filters
# careful, order matches since some things fall into two exp.
df.loc[cat_maintenance, "PPMS_category"] = "PPMS_Maintenance"
df.loc[cat_paid_projects, "PPMS_category"] = "PPMS_Projects"
df.loc[cat_unpaid_projects, "PPMS_category"] = "PPMS_Trials"
df.loc[cat_rd_personal_dev, "PPMS_category"] = "PPMS_RD_Personal"
df.loc[cat_rd_other, "PPMS_category"] = "PPMS_RD"
df.loc[cat_teaching, "PPMS_category"] = "PPMS_Teaching"

# define groups of users: so far only IDA
users_labels = df.System.unique()
users_filters = [df.System == u for u in users_labels]
users = list(zip(users_labels, users_filters))
users.append(("IDA", cat_ida))

# ---------------------------------------------------------- displaying stats

# if activity brings [0,40)CHF income it is assumed that its duration is equal to the number of hours recorded
# When the income is suggesting more than 40CHF / hour duration is COMPUTED such as each 40CHF correspond to one hour
metrics = "Hour's value"
#metrics = 'Total Booked Hours'

# do text outputs and compute useful stats
print('# Summary: PPMS_project AVG booked hours using metrics ' + metrics )
u_in_years = df.groupby("Year")["System"].nunique()
print(df[ df.PPMS_category == "PPMS_Projects" ].groupby(['Year'])[ metrics ].aggregate(np.sum) / u_in_years)
print('\n')

print('# Summary: Total income from PPMS_projects' )
print(df[ df.PPMS_category == "PPMS_Projects" ].groupby(['Year'])[ 'Total Charged [CHF]' ].aggregate(np.sum))
print('\n')

with pd.option_context('display.max_rows', None, 'display.max_columns', 3):
    for cat in pd.unique(df.PPMS_category):
        print('# Summary: '+ cat+' hours computed using metrics ' + metrics )
        print(df[ df.PPMS_category == cat].groupby([ 'Year', 'System'])[ metrics ].sum().round(0))
        print('\n')
    print('# Summary: Total booked hours computed using metrics ' + metrics )
    print(df.groupby([ 'Year', 'System'])[ metrics ].sum().round(0))
    print('\n')
    print('# Summary: Total booked hours computed using metrics ' + metrics )
    print(df.groupby([ 'Year', 'System', 'PPMS_category'])[ metrics ].sum().round(0))
    print('\n')
    print('# Summary: Total booked hours computed using metrics ' + metrics )
    print(df.groupby([ 'Year', 'System', 'PPMS_category', 'Project' ])[ metrics ].sum().round(0))
    print('\n')

# do plots by PPMS_category
for cat in pd.unique(df.PPMS_category):
    df[ df.PPMS_category == cat ].groupby(['Year', 'System'])[ metrics ].aggregate(np.sum).unstack().plot(kind = 'bar', title = u[ 0 ]+': by Year, '+cat).legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.ylabel(metrics)
    plt.show()    

# do plots foir each user
for u in users:
    df[ u[1] ].groupby(['Year'])[ metrics ].aggregate(np.sum).plot(kind = 'bar', title = u[ 0 ]+': by Year, total PPMS_hours').legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.ylabel(metrics)
    plt.show()
    
for u in users:
    df[ u[1] ].groupby(['Year', 'PPMS_category'])[ metrics ].aggregate(np.sum).unstack().plot(kind = 'bar', title = u[ 0 ]+': by Year, PPMS_category').legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.ylabel(metrics)
    plt.show()
# Out:
# # Summary: PPMS_project AVG booked hours using metrics Hour's value
# Year
# 2016    233.128475
# 2017    233.073633
# dtype: float64
#
#
# # Summary: Total income from PPMS_projects
# Year
# 2016    253465.42
# 2017    242898.36
# Name: Total Charged [CHF], dtype: float64
#
#
# # Summary: PPMS_Projects hours computed using metrics Hour's value
# Year  System
# 2016  Barthazy Eszter          177.0
#       Bittermann Anne-Greet    358.0
#       Bodizs Gabriella          46.0
#       Gasser Philippe          369.0
#       Gerstl Stephan            77.0
#       Gramm Fabian             214.0
#       Günthert Maja            294.0
#       Handschin Stephan        350.0
#       Hehl Joachim             339.0
#       Kunze Karsten            543.0
#       Kusch Justine            200.0
#       Lee Sung Sik              58.0
#       Lucas Falk               210.0
#       Lucas Miriam             271.0
#       Meier Roger              215.0
#       Morales Luiz             108.0
#       Noerrelykke Simon        390.0
#       Pinotsi Dorothea          13.0
#       Reuteler Joakim          463.0
#       Rodighiero Simona        100.0
#       Rzepiela Andrzej          30.0
#       Schwarz Tobias           217.0
#       Schäublin Robin          306.0
#       Sologubenko Alla         332.0
#       Stebler Michael          209.0
#       Steiner Miriam            30.0
#       Stoma Szymon             609.0
#       Tittman Peter            110.0
#       Zaubitzer Christian      356.0
# 2017  Barthazy Eszter          228.0
#       Bittermann Anne-Greet    748.0
#       Bodizs Gabriella         325.0
#       Gasser Philippe          116.0
#       Gerstl Stephan           298.0
#       Gramm Fabian             139.0
#       Günthert Maja            149.0
#       Handschin Stephan        416.0
#       Hehl Joachim             300.0
#       Kunze Karsten            403.0
#       Kusch Justine            122.0
#       Lee Sung Sik             122.0
#       Lucas Falk                14.0
#       Lucas Miriam             176.0
#       Meier Roger              153.0
#       Minikus Eugenia            2.0
#       Morales Luiz             381.0
#       Noerrelykke Simon        249.0
#       Pinotsi Dorothea          72.0
#       Reuteler Joakim          352.0
#       Rodighiero Simona        286.0
#       Rzepiela Andrzej         285.0
#       Schwarz Tobias           171.0
#       Schäublin Robin          160.0
#       Sologubenko Alla         294.0
#       Stebler Michael          107.0
#       Stoma Szymon             455.0
#       Tittman Peter            175.0
#       Zaubitzer Christian      294.0
# Name: Hour's value, dtype: float64
#
#
# # Summary: PPMS_Maintenance hours computed using metrics Hour's value
# Year  System
# 2016  Barthazy Eszter            10.0
#       Bittermann Anne-Greet      28.0
#       Bodizs Gabriella          464.0
#       Briand Christophe        1397.0
#       Gasser Philippe           163.0
#       Gerstl Stephan             65.0
#       Gramm Fabian               39.0
#       Günthert Maja             301.0
#       Handschin Stephan         180.0
#       Hehl Joachim              275.0
#       Kunze Karsten             256.0
#       Kusch Justine             270.0
#       Lee Sung Sik              294.0
#       Lucas Falk                676.0
#       Lucas Miriam              201.0
#       Meier Roger               294.0
#       Morales Luiz               16.0
#       Noerrelykke Simon         133.0
#       Pinotsi Dorothea           36.0
#       Reuteler Joakim           169.0
#       Rodighiero Simona         232.0
#       Schwarz Tobias            784.0
#       Schäublin Robin            42.0
#       Sologubenko Alla            3.0
#       Stebler Michael           526.0
#       Steiner Miriam             28.0
#       Stoma Szymon              177.0
#       Tittman Peter             353.0
#       Zaubitzer Christian       708.0
0
# Name: Hour's value, dtype: float64
#
#
# # Summary: Total booked hours computed using metrics Hour's value
# Year  System
# 2016  Barthazy Eszter           347.0
#       Bittermann Anne-Greet    1116.0
#       Bodizs Gabriella          581.0
#       Briand Christophe        1675.0
#       Gasser Philippe           826.0
#       Gerstl Stephan            302.0
#       Gramm Fabian              706.0
#       Günthert Maja             940.0
#       Handschin Stephan         794.0
#       Hehl Joachim             1238.0
#       Kunze Karsten            1341.0
#       Kusch Justine             860.0
#       Lee Sung Sik              923.0
#       Lucas Falk               1294.0
#       Lucas Miriam              846.0
#       Meier Roger              1152.0
#       Morales Luiz              363.0
#       Noerrelykke Simon        1281.0
#       Pinotsi Dorothea          190.0
#       Reuteler Joakim          1132.0
#       Rodighiero Simona        1313.0
#       Rzepiela Andrzej           30.0
#       Schwarz Tobias           1547.0
#       Schäublin Robin           806.0
#       Sologubenko Alla          438.0
#       Stebler Michael           825.0
#       Steiner Miriam            120.0
#       Stoma Szymon             1458.0
#       Tittman Peter             471.0
#       Zaubitzer Christian      1448.0
# 2017  Barthazy Eszter           397.0
#       Bittermann Anne-Greet    1302.0
#       Bodizs Gabriella         1410.0
#       Briand Christophe        1564.0
#       Gasser Philippe           401.0
#       Gerstl Stephan            890.0
#       Gramm Fabian              460.0
#       Günthert Maja             829.0
#       Handschin Stephan         825.0
#       Hehl Joachim             1223.0
#       Kunze Karsten             885.0
#       Kusch Justine             797.0
#       Lee Sung Sik              927.0
#       Lucas Falk                994.0
#       Lucas Miriam              680.0
#       Meier Roger               897.0
#       Minikus Eugenia             2.0
#       Morales Luiz              765.0
#       Noerrelykke Simon        1177.0
#       Pinotsi Dorothea         1466.0
#       Reuteler Joakim          1106.0
#       Rodighiero Simona        1099.0
#       Rzepiela Andrzej         1627.0
#       Schwarz Tobias           1492.0
#       Schäublin Robin           396.0
#       Sologubenko Alla          343.0
#       Stebler Michael           595.0
#       Stoma Szymon             1474.0
#       Tittman Peter             394.0
#       Zaubitzer Christian      1247.0
# Name: Hour's value, dtype: float64
#
#
# # Summary: Total booked hours computed using metrics Hour's value
# Year  System                 PPMS_category
# 2016  Barthazy Eszter        PPMS_Maintenance      10.0
#                              PPMS_Projects        177.0
#                              PPMS_RD_Personal      23.0
#                              PPMS_Teaching        135.0
#                              PPMS_Trials            2.0
#       Bittermann Anne-Greet  PPMS_Maintenance      28.0
#                              PPMS_Projects        358.0
#                              PPMS_RD_Personal     386.0
#                              PPMS_Teaching        243.0
#                              PPMS_Trials          100.0
#       Bodizs Gabriella       PPMS_Maintenance     464.0
#                              PPMS_Projects         46.0
#                              PPMS_RD               18.0
#                              PPMS_RD_Personal      51.0
#                              PPMS_Trials            3.0
#       Briand Christophe      PPMS_Maintenance    1397.0
#                              PPMS_RD_Personal     278.0
#       Gasser Philippe        PPMS_Maintenance     163.0
#                              PPMS_Projects        369.0
#                              PPMS_RD_Personal     156.0
#                              PPMS_Teaching         92.0
#                              PPMS_Trials           48.0
#       Gerstl Stephan         PPMS_Maintenance      65.0
#                              PPMS_Projects         77.0
#                              PPMS_RD_Personal      63.0
#                              PPMS_Teaching         34.0
#                              PPMS_Trials           64.0
#       Gramm Fabian           PPMS_Maintenance      39.0
#                              PPMS_Projects        214.0
#                              PPMS_RD_Personal     156.0
#                              PPMS_Teaching        266.0
#                              PPMS_Trials           32.0
#       Günthert Maja          PPMS_Maintenance     301.0
#                              PPMS_Projects        294.0
#                              PPMS_RD_Personal      63.0
#                              PPMS_Teaching        142.0
#                              PPMS_Trials          141.0
#       Handschin Stephan      PPMS_Maintenance     180.0
#                              PPMS_Projects        350.0
#                              PPMS_RD_Personal      36.0
#                              PPMS_Teaching         56.0
#                              PPMS_Trials          172.0
#       Hehl Joachim           PPMS_Maintenance     275.0
#                              PPMS_Projects        339.0
#                              PPMS_RD_Personal     208.0
#                              PPMS_Teaching        166.0
#                              PPMS_Trials          250.0
#       Kunze Karsten          PPMS_Maintenance     256.0
#                              PPMS_Projects        543.0
#                              PPMS_RD_Personal      82.0
#                              PPMS_Teaching        379.0
#                              PPMS_Trials           80.0
#       Kusch Justine          PPMS_Maintenance     270.0
#                              PPMS_Projects        200.0
#                              PPMS_RD_Personal     134.0
#                              PPMS_Teaching         68.0
#                              PPMS_Trials          188.0
#       Lee Sung Sik           PPMS_Maintenance     294.0
#                              PPMS_Projects         58.0
#                              PPMS_RD_Personal     164.0
#                              PPMS_Teaching         86.0
#                              PPMS_Trials          322.0
#       Lucas Falk             PPMS_Maintenance     676.0
#                              PPMS_Projects        210.0
#                              PPMS_RD_Personal     144.0
#                              PPMS_Teaching        139.0
#                              PPMS_Trials          124.0
#       Lucas Miriam           PPMS_Maintenance     201.0
#                              PPMS_Projects        271.0
#                              PPMS_RD_Personal     142.0
#                              PPMS_Teaching        130.0
#                              PPMS_Trials          102.0
#       Meier Roger            PPMS_Maintenance     294.0
#                              PPMS_Projects        215.0
#                              PPMS_RD               24.0
#                              PPMS_RD_Personal     288.0
#                              PPMS_Trials          331.0
#       Morales Luiz           PPMS_Maintenance      16.0
#                              PPMS_Projects        108.0
#                              PPMS_RD_Personal     132.0
#                              PPMS_Teaching         94.0
#                              PPMS_Trials           14.0
#       Noerrelykke Simon      PPMS_Maintenance     133.0
#                              PPMS_Projects        390.0
#                              PPMS_RD               38.0
#                              PPMS_RD_Personal     347.0
#                              PPMS_Teaching        167.0
#                              PPMS_Trials          206.0
#       Pinotsi Dorothea       PPMS_Maintenance      36.0
#                              PPMS_Projects         13.0
#                              PPMS_RD_Personal     104.0
#                              PPMS_Teaching          3.0
#                              PPMS_Trials           34.0
#       Reuteler Joakim        PPMS_Maintenance     169.0
#                              PPMS_Projects        463.0
#                              PPMS_RD_Personal     190.0
#                              PPMS_Teaching        205.0
#                              PPMS_Trials          105.0
#       Rodighiero Simona      PPMS_Maintenance     232.0
#                              PPMS_Projects        100.0
#                              PPMS_RD               19.0
#                              PPMS_RD_Personal     172.0
#                              PPMS_Teaching        750.0
#                              PPMS_Trials           41.0
#       Rzepiela Andrzej       PPMS_Projects         30.0
#       Schwarz Tobias         PPMS_Maintenance     784.0
#                              PPMS_Projects        217.0
#                              PPMS_RD                4.0
#                              PPMS_RD_Personal     129.0
#                              PPMS_Teaching        131.0
#                              PPMS_Trials          283.0
#       Schäublin Robin        PPMS_Maintenance      42.0
#                              PPMS_Projects        306.0
#                              PPMS_RD               50.0
#                              PPMS_RD_Personal     340.0
#                              PPMS_Teaching         42.0
#                              PPMS_Trials           24.0
#       Sologubenko Alla       PPMS_Maintenance       3.0
#                              PPMS_Projects        332.0
#                              PPMS_RD_Personal      74.0
#                              PPMS_Teaching         24.0
#                              PPMS_Trials            6.0
#       Stebler Michael        PPMS_Maintenance     526.0
#                              PPMS_Projects        209.0
#                              PPMS_RD_Personal      58.0
#                              PPMS_Trials           32.0
#       Steiner Miriam         PPMS_Maintenance      28.0
#                              PPMS_Projects         30.0
#                              PPMS_RD_Personal      31.0
#                              PPMS_Teaching         11.0
#                              PPMS_Trials           20.0
#       Stoma Szymon           PPMS_Maintenance     177.0
#                              PPMS_Projects        609.0
#                              PPMS_RD_Personal     276.0
#                              PPMS_Teaching        181.0
#                              PPMS_Trials          214.0
#       Tittman Peter          PPMS_Maintenance     353.0
#                              PPMS_Projects        110.0
#                              PPMS_Trials            8.0
#       Zaubitzer Christian    PPMS_Maintenance     708.0
#                              PPMS_Projects        356.0
#                              PPMS_RD_Personal     262.0
#                              PPMS_Teaching        118.0
#                              PPMS_Trials            4.0
# 2017  Barthazy Eszter        PPMS_Maintenance       9.0
#                              PPMS_Projects        228.0
#                              PPMS_RD_Personal      20.0
#                              PPMS_Teaching        106.0
#                              PPMS_Trials           34.0
#       Bittermann Anne-Greet  PPMS_Maintenance      34.0
#                              PPMS_Projects        748.0
#                              PPMS_RD_Personal     130.0
#                              PPMS_Teaching        295.0
#                              PPMS_Trials           96.0
#       Bodizs Gabriella       PPMS_Maintenance     906.0
#                              PPMS_Projects        325.0
#                              PPMS_RD               12.0
#                              PPMS_RD_Personal     148.0
#                              PPMS_Trials           19.0
#       Briand Christophe      PPMS_Maintenance    1284.0
#                              PPMS_RD_Personal     280.0
#       Gasser Philippe        PPMS_Maintenance      14.0
#                              PPMS_Projects        116.0
#                              PPMS_RD_Personal     157.0
#                              PPMS_Teaching        114.0
#       Gerstl Stephan         PPMS_Maintenance     160.0
#                              PPMS_Projects        298.0
#                              PPMS_RD_Personal     187.0
#                              PPMS_Teaching         59.0
#                              PPMS_Trials          185.0
#       Gramm Fabian           PPMS_Maintenance      30.0
#                              PPMS_Projects        139.0
#                              PPMS_RD_Personal     100.0
#                              PPMS_Teaching        149.0
#                              PPMS_Trials           43.0
#       Günthert Maja          PPMS_Maintenance     240.0
#                              PPMS_Projects        149.0
#                              PPMS_RD_Personal     122.0
#                              PPMS_Teaching        161.0
#                              PPMS_Trials          158.0
#       Handschin Stephan      PPMS_Maintenance     151.0
#                              PPMS_Projects        416.0
#                              PPMS_RD               11.0
#                              PPMS_RD_Personal      60.0
#                              PPMS_Teaching         12.0
#                              PPMS_Trials          175.0
#       Hehl Joachim           PPMS_Maintenance     298.0
#                              PPMS_Projects        300.0
#                              PPMS_RD_Personal     225.0
#                              PPMS_Teaching        100.0
#                              PPMS_Trials          301.0
#       Kunze Karsten          PPMS_Maintenance     184.0
#                              PPMS_Projects        403.0
#                              PPMS_RD_Personal      58.0
#                              PPMS_Teaching        198.0
#                              PPMS_Trials           42.0
#       Kusch Justine          PPMS_Maintenance     253.0
#                              PPMS_Projects        122.0
#                              PPMS_RD_Personal     159.0
#                              PPMS_Teaching         41.0
#                              PPMS_Trials          222.0
#       Lee Sung Sik           PPMS_Maintenance     354.0
#                              PPMS_Projects        122.0
#                              PPMS_RD_Personal     114.0
#                              PPMS_Teaching         56.0
#                              PPMS_Trials          282.0
#       Lucas Falk             PPMS_Maintenance     344.0
#                              PPMS_Projects         14.0
#                              PPMS_RD              488.0
#                              PPMS_RD_Personal       4.0
#                              PPMS_Teaching        118.0
#                              PPMS_Trials           26.0
#       Lucas Miriam           PPMS_Maintenance     106.0
#                              PPMS_Projects        176.0
#                              PPMS_RD                7.0
#                              PPMS_RD_Personal     100.0
#                              PPMS_Teaching        184.0
#                              PPMS_Trials          107.0
#       Meier Roger            PPMS_Maintenance     212.0
#                              PPMS_Projects        153.0
#                              PPMS_RD               46.0
#                              PPMS_RD_Personal     215.0
#                              PPMS_Teaching         55.0
#                              PPMS_Trials          216.0
#       Minikus Eugenia        PPMS_Projects          2.0
#       Morales Luiz           PPMS_Maintenance      67.0
#                              PPMS_Projects        381.0
#                              PPMS_RD_Personal      86.0
#                              PPMS_Teaching        194.0
#                              PPMS_Trials           36.0
#       Noerrelykke Simon      PPMS_Maintenance     140.0
#                              PPMS_Projects        249.0
#                              PPMS_RD                9.0
#                              PPMS_RD_Personal     285.0
#                              PPMS_Teaching        396.0
#                              PPMS_Trials           98.0
#       Pinotsi Dorothea       PPMS_Maintenance     404.0
#                              PPMS_Projects         72.0
#                              PPMS_RD_Personal     698.0
#                              PPMS_Teaching        116.0
#                              PPMS_Trials          176.0
#       Reuteler Joakim        PPMS_Maintenance     289.0
#                              PPMS_Projects        352.0
#                              PPMS_RD_Personal     232.0
#                              PPMS_Teaching        140.0
#                              PPMS_Trials           92.0
#       Rodighiero Simona      PPMS_Maintenance      53.0
#                              PPMS_Projects        286.0
#                              PPMS_RD               45.0
#                              PPMS_RD_Personal      72.0
#                              PPMS_Teaching        563.0
#                              PPMS_Trials           80.0
#       Rzepiela Andrzej       PPMS_Maintenance     960.0
#                              PPMS_Projects        285.0
#                              PPMS_RD_Personal     282.0
#                              PPMS_Teaching          8.0
#                              PPMS_Trials           92.0
#       Schwarz Tobias         PPMS_Maintenance    1009.0
#                              PPMS_Projects        171.0
#                              PPMS_RD                4.0
#                              PPMS_RD_Personal      91.0
#                              PPMS_Teaching         82.0
#                              PPMS_Trials          136.0
#       Schäublin Robin        PPMS_Maintenance      52.0
#                              PPMS_Projects        160.0
#                              PPMS_RD               32.0
#                              PPMS_RD_Personal     120.0
#                              PPMS_Teaching         32.0
#       Sologubenko Alla       PPMS_Projects        294.0
#                              PPMS_Teaching         30.0
#                              PPMS_Trials           18.0
#       Stebler Michael        PPMS_Maintenance     422.0
#                              PPMS_Projects        107.0
#                              PPMS_RD_Personal      37.0
#                              PPMS_Trials           29.0
#       Stoma Szymon           PPMS_Maintenance     196.0
#                              PPMS_Projects        455.0
#                              PPMS_RD               42.0
#                              PPMS_RD_Personal     222.0
#                              PPMS_Teaching        434.0
#                              PPMS_Trials          124.0
#       Tittman Peter          PPMS_Maintenance     218.0
#                              PPMS_Projects        175.0
#       Zaubitzer Christian    PPMS_Maintenance     786.0
#                              PPMS_Projects        294.0
#                              PPMS_RD_Personal      50.0
#                              PPMS_Teaching         98.0
#                              PPMS_Trials           19.0
# Name: Hour's value, dtype: float64
#
#
# # Summary: Total booked hours computed using metrics Hour's value
# Year  System                 PPMS_category     Project
# 2016  Barthazy Eszter        PPMS_Maintenance  _Maintenance                                  10.0
#                              PPMS_Projects     0619_Youn                                      2.0
#                                                1413_Dorwling-Carter_Livie                    10.0
#                                                1438_Knüsel_Philippe                           6.0
#                                                1473_Ochs                                      4.0
#                                                1497_De_Jesus_Alcantara                        7.0
#                                                1507_Armutlulu                                 0.0
#                                                1521_Hofer_Corinne                            14.0
#                                                1561_Beltzung                                 13.0
#                                                1592_Pushkar                                   2.0
#                                                1601_Herzog                                   22.0
#                                                1617_Gogos                                     0.0
#                                                1618_Tschirky                                  2.0
#                                                1620_Benetti                                  24.0
#                                                1658_Larmier                                   0.0
#                                                1674_Kim                                       1.0
#                                                1676_Abbott                                    1.0
#                                                1677_Paramonov                                36.0
#                                                1695_Shoshan                                   0.0
#                                                1697_Danzi                                     0.0
#                                                1713_Savchenko                                 0.0
#                                                1734_Egli                                     10.0
#                                                1738_Hentzen                                  10.0
#                                                1750_Septina                                   0.0
#                                                1761_Taylor                                    4.0
#                                                1796_von_Petersdorff-Campen                    2.0
#                                                1829_Castro                                    3.0
#                              PPMS_RD_Personal  _R+D_PD                                       23.0
#                              PPMS_Teaching     _Microscopy_Program                           92.0
#                                                _Teaching                                     43.0
#                              PPMS_Trials       _Trials_Consulting                             2.0
#       Bittermann Anne-Greet  PPMS_Maintenance  _Maintenance                                  28.0
#                              PPMS_Projects     0811_Schaer                                    4.0
#                                                0998_Ruffray                                  12.0
#                                                1178_Giampietro                               16.0
#                                                1258_Takahashi                                 0.0
#                                                1362_ Walter_Caseri                            3.0
#                                                1483_Tervoort_Studart                         36.0
#                                                1580_Ezbiri                                    4.0
#                                                1619_Cihova                                    6.0
#                                                1662_Conde-Petit                              10.0
#                                                1690_Bircher                                  14.0
#                                                1707_ Zimmermann_Walter                      175.0
#                                                1714_Hoenger                                  15.0
#                                                1722_Vernuccio                                28.0
#                                                1758_Drissner                                  7.0
#                                                1765_Reinhard                                 13.0
#                                                1816_Wang_Jieping                             15.0
#                              PPMS_RD_Personal  _R+D_PD                                      386.0
#                              PPMS_Teaching     _Teaching                                    243.0
#                              PPMS_Trials       _Trials_Consulting                           100.0
#       Bodizs Gabriella       PPMS_Maintenance  _Maintenance                                 464.0
#                              PPMS_Projects     LM/Kutay/Dörner                               32.0
#                                                LM/Oxenius/Kräutler                            7.0
#                                                LM/Rohrer/Zanoni                               3.0
#                                                LM/Stucki/Ribeiro                              3.0
#                              PPMS_RD           _R[[and]]D_PD_R[[and]]D Flu                   18.0
#                              PPMS_RD_Personal  _R+D_PD                                       51.0
#                              PPMS_Trials       _Trials_Consulting                             3.0
#       Briand Christophe      PPMS_Maintenance  _Maintenance                                1397.0
#                              PPMS_RD_Personal  _R+D_PD                                      278.0
#       Gasser Philippe        PPMS_Maintenance  _Maintenance                                 163.0
#                              PPMS_Projects     0301_Liverini                                 13.0
#                                                0310_Sologubenko                               5.0
#                                                0922_Holzer                                   80.0
#                                                0998_Ruffray                                 100.0
#                                                1073 Ramsperger                                4.0
#                                                1250_Le Ferrand                                4.0
#                                                1467_Okle                                      6.0
#                                                1519_Wheeler_YuanXiao                         26.0
#                                                1575_Hu_Chengzhi                               8.0
#                                                1610_Alt                                      10.0
#                                                1653_Ming_Chen                                26.0
#                                                1698_Feng_Junxiao                             46.0
#                                                1800_Keller_Lukas                              6.0
#                                                1810_Keller_Janine                            11.0
#                                                1816_Wang_Jieping                             24.0
#                              PPMS_RD_Personal  _R+D_PD                                      156.0
#                              PPMS_Teaching     _Microscopy_Program                           44.0
#                                                _Teaching                                     47.0
#                              PPMS_Trials       _Trials_Consulting                            48.0
#       Gerstl Stephan         PPMS_Maintenance  _Maintenance                                  65.0
#                              PPMS_Projects     0919_Maiti                                     1.0
#                                                1315_Courty_ISTRESS                            6.0
#                                                1335_Schäublin_Robin                          10.0
#                                                1467_Okle                                      7.0
#                                                1519_Wheeler_YuanXiao                         16.0
#                                                1571_Sliwinski                                 4.0
#                                                1593_Dipanwita_Dutta                           8.0
#                                                1652_Ma_Zhiqiang                               3.0
#                                                1663_Haley                                     8.0
#                                                1664_Mari                                      7.0
#                                                1812_Bloch                                     6.0
#                              PPMS_RD_Personal  _R+D_PD                                       63.0
#                              PPMS_Teaching     _Teaching                                     34.0
#                              PPMS_Trials       _Trials_Consulting                            64.0
#       Gramm Fabian           PPMS_Maintenance  _Maintenance                                  39.0
#                              PPMS_Projects     0659_Mitchell                                 16.0
#                                                0903_Yarema_O                                 10.0
#                                                1002_Natarajan_Shyam                          17.0
#                                                1107_Yang_Ning                                 8.0
#                                                1119_Corrŕ                                     3.0
#                                                1266_Yarema_M                                 16.0
#                                                1304_Shen_Yi                                   2.0
#                                                1438_Knüsel_Philippe                           4.0
#                                                1459_Primc_Darinka                             2.0
#                                                1473_Ochs                                     18.0
#                                                1507_Armutlulu                                 2.0
#                                                1521_Hofer_Corinne                             6.0
#                                                1545_Colombo                                   4.0
#                                                1618_Tschirky                                 12.0
#                                                1657_Lin_Tsung-Han                             2.0
#                                                1658_Larmier                                   1.0
#                                                1675_Bouville                                  4.0
#                                                1691_Petta_Dalila                             42.0
#                                                1692_Protesescu                                2.0
#                                                1713_Savchenko                                 9.0
#                                                1738_Hentzen                                   0.0
#                                                1762_Benin                                    18.0
#                                                1789_Mihailovic                                1.0
#                                                1801_Schinhammer                               5.0
#                                                1807_Aramesh                                   8.0
#                              PPMS_RD_Personal  _R+D_PD                                      156.0
#                              PPMS_Teaching     _Microscopy_Program                           91.0
#                                                _Teaching                                    174.0
#                              PPMS_Trials       _Trials_Consulting                            32.0
#       Günthert Maja          PPMS_Maintenance  _Maintenance                                 301.0
#                              PPMS_Projects     1041_Mitchell                                 18.0
#                                                LM/Sanchez-Rodriguez/Sancho                    4.0
#                                                LM/Studart/Demirörs                            1.0
#                                                LM/Studart/Masania                             4.0
#                                                LM/Tröster/Varga                               6.0
#                                                LM/Velicer/LaFortezza                          3.0
#                                                LM/Vogel/Fernandes                             2.0
#                                                LM/Vogel/Jain                                  1.0
#                                                LM/Vorholt/Gäbelein                            4.0
#                                                LM/Vörös/Matter                                3.0
#                                                LM/Winter/Sigmund                              0.0
#                                                LM/Wolfrum/Sun                                 2.0
#                                                LM/Würtz-Kozak/Rütsche                         4.0
#                                                LM/Zeeman/Truernit                             2.0
#                                                LM/Zenobi-Wong/Broguiere                       1.0
#                              PPMS_RD           _R[[and]]D_PD_R[[and]]D Crispr                 4.0
#                              PPMS_RD_Personal  _R+D_PD                                       90.0
#                                                _R[[and]]D_PD_Nanolathe                        1.0
#                              PPMS_Teaching     _Microscopy_Program                           31.0
#                                                _Teaching                                     51.0
#                              PPMS_Trials       _Trials_Consulting                           136.0
#       Schäublin Robin        PPMS_Maintenance  _Maintenance                                  52.0
#                              PPMS_Projects     0659_Mitchell                                  6.0
#                                                1403_Enchev_Radoslav                           2.0
#                                                1507_Armutlulu                                 2.0
#                                                1561_Beltzung                                  4.0
#                                                1636_Rossinelli                                0.0
#                                                1676_Abbott                                   12.0
#                                                1695_Shoshan                                   1.0
#                                                1713_Savchenko                                 1.0
#                                                1735_Dai                                      15.0
#                                                1748_Abolhassani-Dadras                        8.0
#                                                1879_Rotzetter                                72.0
#                                                1897_Schäublin                                38.0
#                              PPMS_RD           ETHProj201_CuVIEW                             32.0
#                              PPMS_RD_Personal  _R+D_PD                                      120.0
#                              PPMS_Teaching     _Teaching                                     32.0
#       Sologubenko Alla       PPMS_Projects     0033_Kägi                                      3.0
#                                                0310_Sologubenko                               2.0
#                                                0962_Tervoort                                 25.0
#                                                1204_Reiser                                    2.0
#                                                1207_Reiser                                   14.0
#                                                1354_Mushtaq_Fajer                            21.0
#                                                1467_Okle                                     42.0
#                                                1468_Hoop                                      6.0
#                                                1519_Wheeler_YuanXiao                         12.0
#                                                1593_Dipanwita_Dutta                           8.0
#                                                1653_Ming_Chen                                21.0
#                                                1670_Galinski                                  8.0
#                                                1697_Danzi                                     8.0
#                                                1698_Feng_Junxiao                             25.0
#                                                1813_Schnabel                                 30.0
#                                                1825_Pierobon                                  2.0
#                                                1864_Zhang                                    20.0
#                                                1887_Engel                                    10.0
#                                                1903_Balaghi                                   6.0
#                                                1905_Cheng_Bojun                               4.0
#                                                1909_Keevend                                  12.0
#                                                1945_Moser                                     4.0
#                                                1965_Quan_Wei                                  4.0
#                                                1968_Alvarez_Frances                           5.0
#                              PPMS_Teaching     _Microscopy_Program                           30.0
#                              PPMS_Trials       _Trials_Consulting                            18.0
#       Stebler Michael        PPMS_Maintenance  _Maintenance                                 422.0
#                              PPMS_Projects     LM/Hardt/Nishimura                            13.0
#                                                LM/Kutay/Dörner                               64.0
#                                                LM/Rohrer/Velagapudi                           2.0
#                                                LM/Stucki/Ribeiro                             28.0
#                              PPMS_RD_Personal  _R+D_PD                                       37.0
#                              PPMS_Trials       _Trials_Consulting                            29.0
#       Stoma Szymon           PPMS_Maintenance  _Maintenance                                 196.0
#                              PPMS_Projects     1848_Hochmuth                                 24.0
#                                                LM/Barral/Sliwa-Gonzalez                      12.0
#                                                LM/Blanc/Müller                               10.0
#                                                LM/DeBock/Hulst                               16.0
#                                                LM/Halin/Russo                                30.0
#                                                LM/Hardt/Kolinko                              16.0
#                                                LM/Prats/Prats                               124.0
#                                                LM/Rohrer/Zanoni                              28.0
#                                                LM/Rudin/Lehmann                             114.0
#                                                LM/Sturla/Mueller                              1.0
#                                                LM/inSpehro/Strassfeld                        80.0
#                              PPMS_RD           _R[[and]]D_PD_R[[and]]D CellStar              42.0
#                              PPMS_RD_Personal  _R+D_PD                                      222.0
#                              PPMS_Teaching     _R+D_PD_MOOC_01                               74.0
#                                                _Teaching                                    361.0
#                              PPMS_Trials       _Trials_Consulting                           124.0
#       Tittman Peter          PPMS_Maintenance  _Maintenance                                 218.0
#                              PPMS_Projects     0912_                                          6.0
#                                                1316_Richmond/Frouws                          18.0
#                                                1442_Sazanov_Leonid                            8.0
#                                                1595_Milla_Astals_Maria                        8.0
#                                                1634_Wang_Haibo                                4.0
#                                                1649_Kwiatkowski                               5.0
#                                                1666_Ishikawa                                 10.0
#                                                1686_Tacke                                     5.0
#                                                1767_Korkhov                                  25.0
#                                                1778_Dedic                                     4.0
#                                                1779_Campagne                                 16.0
#                                                1803_Mori_Takahiro                             6.0
#                                                1824_Wild_Rebekka                              6.0
#                                                1832_Ghosh                                     5.0
#                                                1834_Clement                                   5.0
#                                                1843_Kissling                                 10.0
#                                                1847_Campioni                                  1.0
#                                                1862_Zdanowicz                                19.0
#                                                1874_Malinovska                                1.0
#                                                1881_Barth                                     8.0
#                                                1941_Cao_Yiping                                5.0
#                                                1983_Mäeots                                    1.0
#       Zaubitzer Christian    PPMS_Maintenance  _Maintenance                                 786.0
#                              PPMS_Projects     0922_Holzer                                   31.0
#                                                1089_Hosseini                                  1.0
#                                                1304_Shen_Yi                                   4.0
#                                                1354_Mushtaq_Fajer                             6.0
#                                                1413_Dorwling-Carter_Livie                    20.0
#                                                1468_Hoop                                      8.0
#                                                1497_De_Jesus_Alcantara                        4.0
#                                                1519_Wheeler_YuanXiao                          3.0
#                                                1561_Beltzung                                 14.0
#                                                1567_Koulialias                                4.0
#                                                1577_Hambitzer                                15.0
#                                                1589_Cihova                                    4.0
#                                                1617_Gogos                                     8.0
#                                                1622_Vorobyeva                                 4.0
#                                                1676_Abbott                                    4.0
#                                                1685_Tacke                                    14.0
#                                                1686_Tacke                                    24.0
#                                                1695_Shoshan                                  18.0
#                                                1713_Savchenko                                 8.0
#                                                1795_Mule_Aniket_Sandip                       32.0
#                                                1807_Aramesh                                   6.0
#                                                1813_Schnabel                                 13.0
#                                                1861_Diamantopoulou                            4.0
#                                                1905_Cheng_Bojun                              22.0
#                                                1913_Intlekofer                               16.0
#                                                1940_Lauener                                   6.0
#                              PPMS_RD_Personal  _R+D_PD                                       50.0
#                              PPMS_Teaching     _Microscopy_Program                           98.0
#                              PPMS_Trials       _Trials_Consulting                            19.0
# Name: Hour's value, dtype: float64
